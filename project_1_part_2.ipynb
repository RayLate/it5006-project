# %%
import pandas as pd

# %%
df = pd.read_csv("./population_indicators.csv")

# %%
df.transpose()
# Out:
#                                     0                             1   \
# Data Series  Total Population (Number)  Resident Population (Number)
# 2021                         5,453,566                     3,986,842
# 2020                         5,685,807                     4,044,210
# 2019                         5,703,569                     4,026,209
# 2018                         5,638,676                     3,994,283
# ...                                ...                           ...
# 1954                         1,248,200                            na
# 1953                         1,191,800                            na
# 1952                         1,127,000                            na
# 1951                         1,068,100                            na
# 1950                         1,022,100                            na
#
#                                                 2   \
# Data Series  Singapore Citizen Population (Number)
# ...

# %%
dwellings = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/IT5006/Project 1/dwellings.csv")

# %%
dwellings
# Out:
#                             Data Series       2021       2020       2019  \
# 0                             Residents  3,986,842  4,044,210  4,026,209
# 1                   Total HDB Dwellings  3,090,959  3,152,410  3,154,524
# 2               HDB 1- And 2-Room Flats    179,559    177,358    173,771
# 3                      HDB 3-Room Flats    557,100    575,200    580,233
# 4                      HDB 4-Room Flats  1,312,346  1,338,374  1,337,743
# ..                                  ...        ...        ...        ...
# 175                    HDB 4-Room Flats      5,632      5,346      4,898
# 176      HDB 5-Room And Executive Flats      3,925      3,745      3,503
# 177     Condominiums & Other Apartments      1,363      1,255      1,187
# 178                   Landed Properties      2,613      2,453      2,271
# 179             Other Types Of Dwelling      2,674      2,531      2,431
#
#           2018       2017       2016       2015       2014       2013  ...  \
# ...

# %%
dwellings_dataframes = []
for i in range(0,dwellings.shape[0],9):
  dwellings_dataframes.append(dwellings.iloc[i:i+9,:].transpose())

# %%
residents_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/IT5006/Project 1/singapore_residents_by_age_group_ethnicity_sex.csv")

# %%
residents_dataframes = []
for i in range(0,residents_data.shape[0],25):
  residents_dataframes.append(residents_data.iloc[i:i+25,:].transpose())

residents_dataframes[0]
# Out:
#                           0              1              2                3   \
# Data Series  Total Residents    0 - 4 Years    5 - 9 Years    10 - 14 Years
# 2021               3,986,842        178,435        198,760          199,993
# 2020               4,044,210        183,076        198,737          206,393
# 2019               4,026,209        185,355        197,775          207,926
# 2018               3,994,283        185,528        199,066          206,530
# ...                      ...            ...            ...              ...
# 1961               1,702,400        303,700        258,900          217,400
# 1960               1,646,400        297,000        250,300          200,300
# 1959               1,587,200        288,800        241,000          175,700
# 1958               1,518,800        277,800        229,600          157,100
# 1957               1,445,929        264,727        218,097          136,280
#
# ...
